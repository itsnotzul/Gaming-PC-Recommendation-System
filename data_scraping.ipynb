# %% [markdown]
# ## Scrapping C-Zone and Brightstar Online Store

# %%
from bs4 import BeautifulSoup
import requests
import pandas as pd
import datetime

# %%
pd.set_option('display.max_rows', 60) # Default 60, otherwise None (to see all)

# %%
url = 'https://brightstarcomp.com/collections/pc-components?sort_by=title-ascending&page=1&filter.v.price.gte=&filter.v.price.lte=&filter.p.product_type=Processor'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

# %%
print(soup)

# %%
products = soup.find('div', class_='right-products')
products = products.find_all('div', class_='product-item')
print(products[0])

# %%
def extract_product_details(product):
    """
    Extracts the URL, name, and price from a product item.

    Args:
        product (BeautifulSoup object): A single product item.

    Returns:
        dict: A dictionary containing the product's URL, name, and price.
    """
    # Extract the component URL
    url = product.find('a')['href']
    full_url = f"https://brightstarcomp.com{url}"  # Add the base URL

    # Extract the component name
    name = product.find('p', class_='product-title').text.strip()

    # Extract the price
    price = product.find('p', class_='price').text.strip()

    # Return the extracted details as a dictionary
    return {
        'url': full_url,
        'name': name,
        'price': price,
        'timestamp': datetime.datetime.now()
    }

""" 
Extract details for all products in each category.
For: Brightstar Computer Website
As of: 19th March 2025
"""

i = 1
product_list = []
product_type = 'PC Accessories'
while(True):
    url = f'https://brightstarcomp.com/collections/pc-components?sort_by=title-ascending&page={i}&filter.v.price.gte=&filter.v.price.lte=&filter.p.product_type={product_type}'
    page = requests.get(url)
    soup = BeautifulSoup(page.text, 'html')

    products = soup.find('div', class_='right-products')
    products = products.find_all('div', class_='product-item')

    if len(products) == 0:
        break
    product_list += [extract_product_details(product) for product in products]
    i += 1

# Convert the list of dictionaries into a Pandas DataFrame
df = pd.DataFrame(product_list)
df['Note'] = None

# Print the DataFrame
display(df)

# Save the DataFrame to a CSV file
df.to_csv(f'data/parts/brightstarcomp/{product_type.lower().strip()}.csv', index=False)
# Out:
#                                                   url  \
# 0   https://brightstarcomp.com/collections/pc-comp...
# 1   https://brightstarcomp.com/collections/pc-comp...
# 2   https://brightstarcomp.com/collections/pc-comp...
# 3   https://brightstarcomp.com/collections/pc-comp...
# 4   https://brightstarcomp.com/collections/pc-comp...
# ..                                                ...
# 62  https://brightstarcomp.com/collections/pc-comp...
# 63  https://brightstarcomp.com/collections/pc-comp...
# 64  https://brightstarcomp.com/collections/pc-comp...
# 65  https://brightstarcomp.com/collections/pc-comp...
# 66  https://brightstarcomp.com/collections/pc-comp...
#
#                                                  name      price  \
# 0   1st Player ARGB Silicon Sleeved Extension Cabl...  RM 130.00
# 1    1st-player-steampunk-gold-series-psu-350mm-cable   RM 75.00
# 2   ADATA XPG Prime ARGB Extension For VGA Sleeved...  RM 149.00
# 3   Arctic A-RGB Controller with RF Remote Control...   RM 74.00
# 4                     Arctic Case PWM Sharing Fan Hub   RM 49.00
# ..                                                ...        ...
# 62  Thermalright Intel LGA 1700 Air Cooler Refit B...   RM 15.00
# 63  Thermalright Intel LGA1700 Bending Corrector F...   RM 35.00
# 64  Thermaltake LCD Panel Kit for The Tower 500 - ...   RM 99.00
# 65  Thermaltake The Tower 300 Chassis Stand Kit - ...  RM 129.00
# 66  Unitek 5 in 1 External Optical Drive with USB Hub  RM 139.00
#
#                     timestamp  Note
# 0  2025-04-02 18:59:57.131359  None
# 1  2025-04-02 18:59:57.131359  None
# 2  2025-04-02 18:59:57.131359  None
# 3  2025-04-02 18:59:57.131359  None
# 4  2025-04-02 18:59:57.131359  None
# ..                        ...   ...
# 62 2025-04-02 18:59:58.265344  None
# 63 2025-04-02 18:59:58.265344  None
# 64 2025-04-02 18:59:58.265344  None
# 65 2025-04-02 18:59:58.265344  None
# 66 2025-04-02 18:59:58.265344  None
#
# [67 rows x 5 columns]

# %%
def extract_product_details(product):
    try:
        # Extract the component URL
        url = product.find('a', class_='product-item-link')['href']

        # Extract the component name
        name = product.find('strong', class_='product name product-item-name').text.strip()

        # Extract the price
        price_tag = product.find('span', class_='price-wrapper')
        price = price_tag['data-price-amount'] if price_tag else None  # Handle missing price

        # Return the extracted details as a dictionary
        return {
            'url': url,
            'name': name,
            'price': price,
            'timestamp': datetime.datetime.now()
        }
    except AttributeError as e:
        print(f"Error extracting product details: {e}")
        return None

# %%
import os

""" 
Extract details for all products in each category.
For: C-zone Website
As of: 19th March 2025
"""
components_done = ['cpu-processors', 'memory', 'motherboards','video-card-video-devices']
components = ['computer-cases', 'power-supplies', 'fan-pc-cooling', 'sound-cards', 'optical-drives']
output_dir = 'data/parts/czone/'
os.makedirs(output_dir, exist_ok=True)

for component in components:
    product_list = []
    seen_products = set()  # To track unique product URLs
    i = 1

    while True:
        # Scrape page
        url = f'https://czone.my/czone/computer-components/core-components/{component}.html?p={i}'
        page = requests.get(url)
        if page.status_code != 200:
            print(f"Failed to fetch {url}, status code: {page.status_code}")
            break

        soup = BeautifulSoup(page.text, 'html')

        # Extract data
        products_container = soup.find('div', class_='products wrapper grid products-grid')
        if not products_container:
            print(f"No products found on page {i} for component {component}")
            break

        products = products_container.findAll('li', class_='item product product-item')
        if len(products) == 0:
            break

        for product in products:
            product_details = extract_product_details(product)
            if product_details:
                product_url = product_details['url']  # Use URL as a unique identifier
                if product_url in seen_products:
                    print(f"Duplicate product detected: {product_url}. Stopping.")
                    break  # Stop processing further pages
                seen_products.add(product_url)
                product_list.append(product_details)
        else:
            # Continue to the next page if no duplicates were found
            i += 1
            continue

        # Break the outer loop if a duplicate is found
        break

    df = pd.DataFrame(product_list)
    df['Note'] = None

    # Save the DataFrame to a CSV file
    df.to_csv(f'{output_dir}{component}.csv', index=False, encoding='utf-8')
# Out:
# Duplicate product detected: https://czone.my/czone/nzxt-h9-computer-case.html. Stopping.
# Duplicate product detected: https://czone.my/czone/mag a750bn pcie5-1739103631.html. Stopping.
# Duplicate product detected: https://czone.my/czone/idc-hub-fh-07-1739103466.html. Stopping.
# Duplicate product detected: https://czone.my/czone/cdkhb-1737817497.html. Stopping.
# Duplicate product detected: https://czone.my/czone/mr193bk-1739103713.html. Stopping.

# %%
url = 'https://czone.my/czone/computer-components/core-components/computer-cases.html?p=1'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

products = soup.find('div', class_='products wrapper grid products-grid')
products = products.findAll('li', class_='item product product-item')
products_list = [extract_product_details(product) for product in products]
df = pd.DataFrame(products_list)

display(df)
# Out:
#                                                   url  \
# 0   https://czone.my/czone/phanteks-nv5s-computer-...
# 1   https://czone.my/czone/deepcool-ch260-matx-com...
# 2   https://czone.my/czone/tecware-timber-m-tg-com...
# 3   https://czone.my/czone/pa401/bk/wood/tg-174192...
# 4    https://czone.my/czone/pc-o11vpw-1739103813.html
# 5   https://czone.my/czone/twca-vxprm-bkar-1739107...
# 6   https://czone.my/czone/lian-li-a4-h2o-computer...
# 7   https://czone.my/czone/twca-fus2a-bk-173910708...
# 8   https://czone.my/czone/twca-edm2-bkol-17391070...
# 9   https://czone.my/czone/gfg-p2storm-1739103401....
# 10  https://czone.my/czone/gfg-p1gateway-173910340...
# 11  https://czone.my/czone/twca-edair-bk-173910708...
# 12  https://czone.my/czone/twca-nexat3-bkol-173910...
# 13  https://czone.my/czone/twca-nexam3-bkol-173910...
# 14      https://czone.my/czone/a3x-wd-1739106872.html
# 15  https://czone.my/czone/tecware-arc-argb-curved...
# 16  https://czone.my/czone/tecware-arc-m-argb-curv...
# 17  https://czone.my/czone/nzxt-h5-flow-2024-compu...
# 18  https://czone.my/czone/jonsbo-c6-computer-case...
# 19  https://czone.my/czone/tecware-neo-m2-omni-tg-...
# 20  https://czone.my/czone/nzxt-h5-flow-2024-rgb-c...
# 21  https://czone.my/czone/tecware-vx-trinity-m-ar...
# 22  https://czone.my/czone/tecware-timber-tg-compu...
# 23  https://czone.my/czone/tecware-infinity-m-argb...
# 24  https://czone.my/czone/deepcool-ch170-digital-...
# 25  https://czone.my/czone/deepcool-cg580-computer...
# 26     https://czone.my/czone/bx-mini-1739103183.html
# 27  https://czone.my/czone/nzxt-h7-flow-2024-rgb-c...
# 28  https://czone.my/czone/tecware-vxn-evo-omni-co...
# 29  https://czone.my/czone/silverstone-fara-514x-c...
# 30  https://czone.my/czone/sst-fa312x-bg-173910699...
# 31  https://czone.my/czone/montech-xr-computer-cas...
#
#                                                  name price  \
# 0                         Phanteks NV5S Computer Case   449
# 1                   Deepcool CH260 MATX Computer Case   259
# 2                   Tecware Timber M TG Computer Case   179
# 3   Asus ProArt  PA401 Wood Edition Computer Case ...   560
# 4         Lian Li PC-O11 Vision Compact Computer Case  1920
# 5   Tecware VX Prism M Computer Case (mATX, TG, AR...   269
# 6                        Lian Li A4-H2O Computer Case   679
# 7   Tecware Fusion 2 Air Computer Case (mATX, TG, ...   229
# 8   Tecware Edge M2 TG Computer Case (mATX, TG, AR...   169
# 9   Gaming Freak P2 Storm TG Computer Case (mATX, ...   189
# 10  Gaming Freak P1 Gateway TG Computer Case (mATX...   159
# 11  Tecware Edge Air TG Computer Case (ATX, TG, Bl...   199
# 12  Tecware Nexus Air T3 Omni ARGB Computer Case (...   189
# 13  Tecware Nexus Air M3 Omni ARGB Computer Case (...   189
# 14  Lian Li A3 Computer Black Wooden Case (mATX, M...   359
# 15           Tecware ARC ARGB Curved TG Computer Case  None
# 16         Tecware ARC M ARGB Curved TG Computer Case   229
# 17                  NZXT H5 Flow (2024) Computer Case   399
# 18                            Jonsbo C6 Computer Case   159
# 19          Tecware Neo M2 Omni TG ARGB Computer Case   169
# 20              NZXT H5 Flow (2024) RGB Computer Case   539
# 21            Tecware VX Trinity M ARGB Computer Case   259
# 22                    Tecware Timber TG Computer Case  None
# 23              Tecware Infinity M ARGB Computer Case   249
# 24           Deepcool CH170 Digital ITX Computer Case   279
# 25                       Deepcool CG580 Computer Case   269
# 26  X-Five BX Mini Computer Case (mATX, Steel, 500...   130
# 27              NZXT H7 Flow (2024) RGB Computer Case   639
# 28                 Tecware VXN Evo Omni Computer Case   209
# 29                Silverstone Fara 514X Computer Case   269
# 30  Silverstone Fara 312X Computer Case (mATX, TG,...   199
# 31                           Montech XR Computer Case   249
#
#                     timestamp
# 0  2025-03-19 14:37:43.252984
# 1  2025-03-19 14:37:43.254101
# 2  2025-03-19 14:37:43.254101
# 3  2025-03-19 14:37:43.254101
# 4  2025-03-19 14:37:43.254610
# 5  2025-03-19 14:37:43.254610
# 6  2025-03-19 14:37:43.254610
# 7  2025-03-19 14:37:43.255006
# 8  2025-03-19 14:37:43.255006
# 9  2025-03-19 14:37:43.255006
# 10 2025-03-19 14:37:43.255514
# 11 2025-03-19 14:37:43.255514
# 12 2025-03-19 14:37:43.255514
# 13 2025-03-19 14:37:43.256027
# 14 2025-03-19 14:37:43.256027
# 15 2025-03-19 14:37:43.256027
# 16 2025-03-19 14:37:43.256535
# 17 2025-03-19 14:37:43.256535
# 18 2025-03-19 14:37:43.256535
# 19 2025-03-19 14:37:43.257044
# 20 2025-03-19 14:37:43.257044
# 21 2025-03-19 14:37:43.257044
# 22 2025-03-19 14:37:43.257556
# 23 2025-03-19 14:37:43.257556
# 24 2025-03-19 14:37:43.257556
# 25 2025-03-19 14:37:43.258068
# 26 2025-03-19 14:37:43.258068
# 27 2025-03-19 14:37:43.258068
# 28 2025-03-19 14:37:43.258577
# 29 2025-03-19 14:37:43.258577
# 30 2025-03-19 14:37:43.258577
# 31 2025-03-19 14:37:43.259088

# %%
url = f'https://brightstarcomp.com/collections/pc-components?sort_by=title-ascending&page=30&filter.v.price.gte=&filter.v.price.lte=&filter.p.product_type=Processor'
page = requests.get(url)
soup = BeautifulSoup(page.text, 'html')

products = soup.find('div', class_='right-products')
products = products.find_all('div', class_='product-item')
len(products)
# Out:
# 0

# %%
df.to_csv('cpu_test.csv', index=False)

# %% [markdown]
# ## Data Cleaning

# %% [markdown]
# ### CPU

# %%
cpu = pd.read_csv('data/parts/CPU_Data.csv')
bsc_cpu = pd.read_csv('data/parts/brightstarcomp/cpu.csv')
czone_cpu = pd.read_csv('data/parts/czone/cpu-processors.csv')

# %%
print(cpu.columns)
print(bsc_cpu.columns)
# Out:
# Index(['Brand', 'Name', 'Chipset', 'Score', 'Price'], dtype='object')
# Index(['url', 'name', 'price', 'timestamp', 'Note'], dtype='object')

# %%
def parse_cpu_details(product_string):
    """
    Parses a product string into Brand, Name, and Chipset.

    Args:
        product_string (str): The product string to parse.

    Returns:
        dict: A dictionary containing Brand, Name, and Chipset.
    """
    # Split the string into parts
    parts = product_string.split()
    
    # Extract Brand (first word)
    brand = parts[0]
    
    # Extract Chipset (if it contains "LGA" or "AM" as a standalone part)
    chipset = next((part for part in parts if part.startswith("LGA") or part.startswith("AM") and part != "AMD"), None)
    
    # Extract Name (everything between Brand and Chipset)
    if chipset:
        chipset_index = parts.index(chipset)
        name = " ".join(parts[1:chipset_index])
    else:
        name = " ".join(parts[1:])
    
    return {
        "Brand": brand,
        "Name": name,
        "Chipset": chipset
    }
# Name
name_strings = bsc_cpu['name'].tolist() + czone_cpu['name'].tolist()
new_cpu_df = pd.DataFrame([parse_cpu_details(name) for name in name_strings])
# Price
bsc_price_string = bsc_cpu['price'].tolist() 
cleaned_price_string = [price.replace('RM', '').replace(',', '').strip() for price in bsc_price_string]
price_strings = cleaned_price_string + czone_cpu['price'].tolist()
new_cpu_df['Price'] = price_strings
# URL
new_cpu_df['URL'] = bsc_cpu['url'].tolist() + czone_cpu['url'].tolist()
# Timestamp
new_cpu_df['Timestamp'] = bsc_cpu['timestamp'].tolist() + czone_cpu['timestamp'].tolist()
# Note
new_cpu_df['Note'] = None
display(new_cpu_df)
# Out:
#     Brand                          Name  Chipset    Price  \
# 0     AMD                  Athlon 3000G      AM4   219.00
# 1     AMD                 Ryzen 3 3200G      AM4   299.00
# 2     AMD                  Ryzen 5 5500      AM4   409.00
# 3     AMD                  Ryzen 5 5600      AM4   499.00
# 4     AMD                 Ryzen 5 5600G      AM4   549.00
# 5     AMD                Ryzen 5 5600GT      AM4   599.00
# 6     AMD                 Ryzen 5 5600X      AM4   589.00
# 7     AMD                 Ryzen 5 7500F      AM5   749.00
# 8     AMD                  Ryzen 5 7600      AM5   899.00
# 9     AMD                 Ryzen 5 7600X      AM5   999.00
# 10    AMD                 Ryzen 5 8400F      AM5   669.00
# 11    AMD                 Ryzen 5 8500G      AM5   699.00
# 12    AMD                 Ryzen 5 8600G      AM5   799.00
# 13    AMD                 Ryzen 5 9600X      AM5  1349.00
# 14    AMD                 Ryzen 7 5700G      AM4   839.00
# 15    AMD                 Ryzen 7 5700X      AM4   759.00
# 16    AMD               Ryzen 7 5700X3D      AM4  1049.00
# 17    AMD                  Ryzen 7 7700      AM5  1499.00
# 18    AMD                 Ryzen 7 7700X      AM5  1599.00
# 19    AMD               Ryzen 7 7800X3D      AM5  2099.00
# 20    AMD                 Ryzen 7 8700G      AM5  1399.00
# 21    AMD                 Ryzen 7 9700X      AM5  1749.00
# 22    AMD                  Ryzen 9 7900      AM5  1799.00
# 23    AMD                 Ryzen 9 7950X      AM5  2699.00
# 24    AMD               Ryzen 9 7950X3D      AM5  2999.00
# 25    AMD                 Ryzen 9 9900X      AM5  2149.00
# 26    AMD                 Ryzen 9 9950X      AM5  3049.00
# 27  Intel                Core i3-12100F  LGA1700   339.00
# 28  Intel                 Core i3-14100  LGA1700   519.00
# 29  Intel                Core i3-14100F  LGA1700   379.00
# 30  Intel                 Core i5-12400  LGA1700   669.00
# 31  Intel                Core i5-12400F  LGA1700   499.00
# 32  Intel                 Core i5-14400  LGA1700   819.00
# 33  Intel                Core i5-14400F  LGA1700   699.00
# 34  Intel                Core i5-14600K  LGA1700  1139.00
# 35  Intel               Core i5-14600KF  LGA1700  1039.00
# 36  Intel                 Core i7-12700  LGA1700  1249.00
# 37  Intel                Core i7-12700F  LGA1700  1139.00
# 38  Intel                 Core i7-14700  LGA1700  1539.00
# 39  Intel                Core i7-14700F  LGA1700  1439.00
# 40  Intel                Core i7-14700K  LGA1700  1739.00
# 41  Intel               Core i7-14700KF  LGA1700  1639.00
# 42  Intel               Core i9-12900KS  LGA1700  1499.00
# 43  Intel                 Core i9-14900  LGA1700  2729.00
# 44  Intel                Core i9-14900F  LGA1700  2689.00
# 45  Intel                Core i9-14900K  LGA1700  2199.00
# 46  Intel               Core i9-14900KF  LGA1700  2099.00
# 47  Intel               Core i9-14900KS  LGA1700  3299.00
# 48  Intel             Core Ultra 5 245K  LGA1851  1449.00
# 49  Intel            Core Ultra 5 245KF  LGA1851  1349.00
# 50  Intel             Core Ultra 7 265K  LGA1851  1799.00
# 51  Intel            Core Ultra 7 265KF  LGA1851  1749.00
# 52  Intel             Core Ultra 9 285K  LGA1851  2699.00
# 53  Intel            Pentium Gold G7400  LGA1700   409.00
# 54  Intel    Core Ultra 5 235 Processor     None     1099
# 55    AMD     Ryzen 7 9800X3D Processor     None     2599
# 56  Intel   Core Ultra 5 245K Processor     None     1279
# 57  Intel   Core Ultra 9 285K Processor     None     2599
# 58  Intel   Core Ultra 7 265K Processor     None     1569
# 59  Intel  Core Ultra 7 265KF Processor     None     1489
# 60  Intel       Core i3 14100 Processor     None      469
# 61    AMD       Ryzen 7 9700X Processor     None     1649
# 62    AMD       Ryzen 9 9900X Processor     None     1999
# 63    AMD       Ryzen 9 9950X Processor     None     2849
# 64    AMD       Ryzen 5 9600X Processor     None     1249
# 65    AMD       Ryzen 5 8400F Processor     None      679
# 66    AMD       Ryzen 5 8500G Processor     None      659
# 67    AMD     Ryzen 7 5700X3D Processor     None      899
# 68    AMD      Ryzen 5 5500GT Processor     None      499
# 69    AMD      Ryzen 5 5600GT Processor     None      579
# 70  Intel       Core i7 14700 Processor     None     1399
# 71  Intel      Core i7 14700F Processor     None     1299
# 72  Intel      Core i5 14400F Processor     None      609
# 73  Intel       Core i5 14400 Processor     None      699
# 74  Intel     Core i5-14600KF Processor     None      899
# 75  Intel      Core i9 14900K Processor     None     2099
# 76    AMD       Ryzen 5 7500F Processor     None      649
# 77    AMD        Ryzen 9 7900 Processor     None     1649
# 78    AMD        Ryzen 5 7600 Processor     None      869
# 79    AMD        Ryzen 7 7700 Processor     None     1429
# 80    AMD       Ryzen 7 7700X Processor     None     1479
# 81    AMD       Ryzen 5 7600X Processor     None      999
# 82    AMD       Ryzen 9 7950X Processor     None     2399
# 83    AMD       Ryzen 9 7900X Processor     None     1799
# 84    AMD        Ryzen 5 5600 Processor     None      449
# 85    AMD        Ryzen 5 5500 Processor     None      339
# 86    AMD       Ryzen 7 5700X Processor     None      799
# 87  Intel      Core i5 12400F Processor     None      439
# 88  Intel       Core i5 12400 Processor     None      569
# 89    AMD       Ryzen 5 5600G Processor     None      499
# 90    AMD       Ryzen 7 5700G Processor     None      809
# 91    AMD       Ryzen 5 5600X Processor     None      629
# 92    AMD       Ryzen 3 3200G Processor     None      259
#
#                                                   URL  \
]
merged_cpu['Name'] = merged_cpu['Name'].str.replace('Processor', '')
merged_cpu = merged_cpu.where(pd.notnull(merged_cpu), None)
display(merged_cpu)
# Out:
#      Brand                 Name      Chipset  Score    Price  \
# 0      AMD         Athlon 3000G          AM4     -1   219.00
# 1      AMD         Ryzen 3 1200          AM4   6282      100
# 2      AMD         Ryzen 3 3100          AM4  11587      210
# 3      AMD        Ryzen 3 3200G          AM4   7124      300
# 4      AMD        Ryzen 3 3200G          AM4     -1   299.00
# 5      AMD       Ryzen 3 3200G          None     -1      259
# 6      AMD         Ryzen 5 1400          AM4   7747      200
# 7      AMD         Ryzen 5 1600          AM4  12278      180
# 8      AMD        Ryzen 5 3400G          AM4   9242      340
# 9      AMD       Ryzen 5 3400GE          AM4   8879      320
# 10     AMD        Ryzen 5 3500X          AM4  13166      240
# 11     AMD         Ryzen 5 4500          AM4  16118      300
# 12     AMD         Ryzen 5 5500          AM4  19379      350
# 13     AMD         Ryzen 5 5500          AM4     -1   409.00
# 14     AMD        Ryzen 5 5500          None     -1      339
# 15     AMD      Ryzen 5 5500GT          None     -1      499
# 16     AMD         Ryzen 5 5600          AM4  21576      530
# 17     AMD         Ryzen 5 5600          AM4     -1   499.00
# 18     AMD        Ryzen 5 5600          None     -1      449
# 19     AMD        Ryzen 5 5600G          AM4     -1   549.00
# 20     AMD       Ryzen 5 5600G          None     -1      499
# 21     AMD       Ryzen 5 5600GT          AM4     -1   599.00
# 22     AMD      Ryzen 5 5600GT          None     -1      579
# 23     AMD        Ryzen 5 5600X          AM4     -1   589.00
# 24     AMD       Ryzen 5 5600X          None     -1      629
# 25     AMD        Ryzen 5 7500F          AM5     -1   749.00
# 26     AMD       Ryzen 5 7500F          None     -1      649
# 27     AMD         Ryzen 5 7600          AM5     -1   899.00
# 28     AMD        Ryzen 5 7600          None     -1      869
# 29     AMD        Ryzen 5 7600X          AM5     -1   999.00
# 30     AMD       Ryzen 5 7600X          None     -1      999
# 31     AMD        Ryzen 5 8400F          AM5     -1   669.00
# 32     AMD       Ryzen 5 8400F          None     -1      679
# 33     AMD        Ryzen 5 8500G          AM5     -1   699.00
# 34     AMD       Ryzen 5 8500G          None     -1      659
# 35     AMD        Ryzen 5 8600G          AM5     -1   799.00
# 36     AMD        Ryzen 5 9600X          AM5     -1  1349.00
# 37     AMD       Ryzen 5 9600X          None     -1     1249
# 38     AMD        Ryzen 7 3700X          AM4  22521      400
# 39     AMD        Ryzen 7 5700G          AM4  24530      800
# 40     AMD        Ryzen 7 5700G          AM4     -1   839.00
# 41     AMD       Ryzen 7 5700G          None     -1      809
# 42     AMD        Ryzen 7 5700X          AM4  26653      700
# 43     AMD        Ryzen 7 5700X          AM4     -1   759.00
# 44     AMD       Ryzen 7 5700X          None     -1      799
# 45     AMD      Ryzen 7 5700X3D          AM4     -1  1049.00
# 46     AMD     Ryzen 7 5700X3D          None     -1      899
# 47     AMD         Ryzen 7 7700          AM5     -1  1499.00
# 48     AMD        Ryzen 7 7700          None     -1     1429
# 49     AMD        Ryzen 7 7700X          AM5     -1  1599.00
# 50     AMD       Ryzen 7 7700X          None     -1     1479
# 51     AMD      Ryzen 7 7800X3D          AM5     -1  2099.00
# 52     AMD        Ryzen 7 8700G          AM5     -1  1399.00
# 53     AMD        Ryzen 7 9700X          AM5     -1  1749.00
# 54     AMD       Ryzen 7 9700X          None     -1     1649
# 55     AMD     Ryzen 7 9800X3D          None     -1     2599
# 56     AMD         Ryzen 9 7900          AM5     -1  1799.00
# 57     AMD        Ryzen 9 7900          None     -1     1649
# 58     AMD       Ryzen 9 7900X          None     -1     1799
# 59     AMD        Ryzen 9 7950X          AM5     -1  2699.00
# 60     AMD       Ryzen 9 7950X          None     -1     2399
# 61     AMD      Ryzen 9 7950X3D          AM5     -1  2999.00
# 62     AMD        Ryzen 9 9900X          AM5     -1  2149.00
# 63     AMD       Ryzen 9 9900X          None     -1     1999
# 64     AMD        Ryzen 9 9950X          AM5     -1  3049.00
# 65     AMD       Ryzen 9 9950X          None     -1     2849
# 66   Intel    Core Ultra 5 235          None     -1     1099
# 67   Intel    Core Ultra 5 245K      LGA1851     -1  1449.00
# 68   Intel   Core Ultra 5 245K          None     -1     1279
# 69   Intel   Core Ultra 5 245KF      LGA1851     -1  1349.00
# 70   Intel    Core Ultra 7 265K      LGA1851     -1  1799.00
# 71   Intel   Core Ultra 7 265K          None     -1     1569
# 72   Intel   Core Ultra 7 265KF      LGA1851     -1  1749.00
# 73   Intel  Core Ultra 7 265KF          None     -1     1489
# 74   Intel    Core Ultra 9 285K      LGA1851     -1  2699.00
# 75   Intel   Core Ultra 9 285K          None     -1     2599
# 76   Intel       Core i3 14100          None     -1      469
# 77   Intel       Core i3-12100F      LGA1700  14090      380
# 78   Intel       Core i3-12100F      LGA1700     -1   339.00
# 79   Intel        Core i3-14100      LGA1700  15082      500
# 80   Intel        Core i3-14100      LGA1700     -1   519.00
# 81   Intel       Core i3-14100F      LGA1700     -1   379.00
# 82   Intel       Core i5 12400          None     -1      569
# 83   Intel      Core i5 12400F          None     -1      439
# 84   Intel       Core i5 14400          None     -1      699
# 85   Intel      Core i5 14400F          None     -1      609
# 86   Intel        Core i5-10500      LGA1200  13379      430
# 87   Intel        Core i5-11400      LGA1200  16974      650
# 88   Intel        Core i5-12400      LGA1700  19339      650
# 89   Intel        Core i5-12400      LGA1700     -1   669.00
# 90   Intel       Core i5-12400F      LGA1700  19516      500
# 91   Intel       Core i5-12400F      LGA1700     -1   499.00
# 92   Intel        Core i5-13500      LGA1700  31799      800
# 93   Intel        Core i5-14400      LGA1700     -1   819.00
# 94   Intel       Core i5-14400F      LGA1700  25736      700
# 95   Intel       Core i5-14400F      LGA1700     -1   699.00
# 96   Intel       Core i5-14600K      LGA1700     -1  1139.00
# 97   Intel      Core i5-14600KF      LGA1700     -1  1039.00
# 98   Intel     Core i5-14600KF          None     -1      899
# 99   Intel        Core i5-6400T      LGA1151   4280      133
# 100  Intel         Core i5-6500      LGA1151   5623      166
# 101  Intel        Core i5-7500T      LGA1151   5215      200
# 102  Intel        Core i5-8500T  FCLGA1151-2   7721      260
# 64   2025-03-18 22:10:08.565931  None
# 65   2025-03-19 14:21:03.466617  None
# 66   2025-03-19 14:21:03.465617  None
# 67   2025-03-18 22:10:09.453439  None
# 68   2025-03-19 14:21:03.465617  None
# 69   2025-03-18 22:10:09.453439  None
# 70   2025-03-18 22:10:09.453439  None
# 71   2025-03-19 14:21:03.465617  None
# 72   2025-03-18 22:10:09.453439  None
# 73   2025-03-19 14:21:03.466617  None
# 74   2025-03-18 22:10:09.453439  None
# 75   2025-03-19 14:21:03.465617  None
# 76   2025-03-19 14:21:03.466617  None
# 77                         None  None
# 78   2025-03-18 22:10:08.565931  None
# 79                         None  None
# 80   2025-03-18 22:10:08.565931  None
# 81   2025-03-18 22:10:08.565931  None
# 82   2025-03-19 14:21:03.565474  None
# 83   2025-03-19 14:21:03.565474  None
# 84   2025-03-19 14:21:03.468618  None
# 85   2025-03-19 14:21:03.468618  None
# 86                         None  None
# 87                         None  None
# 88                         None  None
# 89   2025-03-18 22:10:08.565931  None
# 90                         None  None
# 91   2025-03-18 22:10:08.565931  None
# 92                         None  None
# 93   2025-03-18 22:10:08.565931  None
# 94                         None  None
# 95   2025-03-18 22:10:08.565931  None
# 96   2025-03-18 22:10:08.565931  None
# 97   2025-03-18 22:10:08.565931  None
# 98   2025-03-19 14:21:03.468618  None
# 99                         None  None
# 100                        None  None
# 101                        None  None
# 102                        None  None
# 103                        None  None
# 104  2025-03-19 14:21:03.467617  None
# 105  2025-03-19 14:21:03.468618  None
# 106  2025-03-18 22:10:08.565931  None
# 107  2025-03-18 22:10:08.565931  None
# 108                        None  None
# 109  2025-03-18 22:10:08.565931  None
# 110  2025-03-18 22:10:08.565931  None
# 111                        None  None
# 112  2025-03-18 22:10:08.565931  None
# 113                        None  None
# 114  2025-03-18 22:10:08.565931  None
# 115                        None  None
# 116  2025-03-19 14:21:03.468618  None
# 117  2025-03-18 22:10:08.565931  None
# 118                        None  None
# 119                        None  None
# 120                        None  None
# 121  2025-03-18 22:10:08.566930  None
# 122  2025-03-18 22:10:08.566930  None
# 123  2025-03-18 22:10:08.566930  None
# 124                        None  None
# 125  2025-03-18 22:10:08.566930  None
# 126  2025-03-18 22:10:08.566930  None
# 127  2025-03-18 22:10:09.453439  None

# %% [markdown]
# Commented out because manually cleaned (don't want to overwrite)

# %%
# merged_cpu.to_csv('data/parts/CPU_Data(new).csv', index=False, encoding='utf-8')

# %% [markdown]
# ### Case

# %%
pd.set_option('display.max_rows', 60) # Default 60, otherwise None (to see all)

# %%
pc_case = pd.read_csv('data/parts/Case_Data.csv')
bsc_case = pd.read_csv('data/parts/brightstarcomp/case.csv')
czone_case = pd.read_csv('data/parts/czone/computer-cases.csv')

# %%
print(f'{pc_case.columns}\n{bsc_case.columns}\n{czone_case.columns}')
# Out:
# Index(['Brand', 'Model', 'Size', 'Color', 'Price'], dtype='object')
# Index(['url', 'name', 'price', 'timestamp', 'Note'], dtype='object')
# Index(['url', 'name', 'price', 'timestamp', 'Note'], dtype='object')

# %%
def parse_case_details(product_string):
    # Split the string into parts
    parts = product_string.split()
    brands = ['1st Player', 'Aerocool', 'Aigo', 'Antec', 'Asus', 'BeQuiet', 'Cooler Master',
              'Corsair', 'Deepcool', 'DeepCool', 'E-SUPERCASE', 'Fractal Design', 'GIGABYTE',
              'Gigabyte', 'HYTE', 'Hyte', 'Invasion', 'Lian Li', 'MAGNIUMGEAR', 'MONTECH', 'Montech', 'MSI', 
              'NZXT', 'Phanteks', 'Segotep', 'Slevcase', 'SSUPD', 'Tecware', 'Thermaltake',
              'X-Five', 'Zalman', 'Gaming Freak', 'Jonsbo', 'Silverstone']
    
    # Extract Brand (check for multi-word matches)
    brand = next((brand for brand in brands if " ".join(parts[:len(brand.split())]) == brand), None)
    
    # Extract Name (everything after Brand)
    if brand:
        brand_index = len(brand.split())  # Get the number of words in the brand
        name = " ".join(parts[brand_index:])
    else:
        name = " ".join(parts)

    # Clean name
    strings = ['Computer Case', 'PC Chassis', 'Pc Chassis', 'Chassis', 'PC Case', 'Pc Case', 'Case']
    for string in strings:
        name = name.replace(string, '').strip()
    
    # Extract extra data (content inside parentheses)
    if '(' in product_string and ')' in product_string:
        start = product_string.find('(')
        end = product_string.find(')')
        extra_data = product_string[start + 1:end]

        # Remove extra data from name
        name = name.replace(product_string[start:end+1], '').strip()
    else:
        extra_data = None

    # Extract size (if available) - ensure exact matches
    sizes = ['Micro-ATX', 'Mini-ITX', 'E-ATX','EATX', 'mATX','MATX', 'ATX', 'ITX']
    size = None
    for s in sizes:
        if f"{s}" in f"{product_string}":
            size = s
            break  # Exit the loop as soon as a match is found

    # Remove size from name if found
    if size:
        name = name.replace(size, '').strip()
    else:
        size = None

    # Extract tower type (if available)
    towers = ['Mid-Tower', 'Mid Tower', 'Full-Tower', 'Full Tower', 'Super-Tower']
    tower = next((t for t in towers if t in product_string), None)

    # Append tower type to extra data if found
    if tower:
        name = name.replace(tower, '').strip()
        if extra_data:
            extra_data += f", {tower}"
        else:
            extra_data = tower

    return {
        "Brand": brand,
        "Name": name,
        "Size": size,
        "Price": None,
        "URL": None,
        "Timestamp": None,
        "Note": extra_data
    }

case_name_strings = bsc_case['name'].tolist() + czone_case['name'].tolist()
new_case_df = pd.DataFrame([parse_case_details(name) for name in case_name_strings])
new_case_df['Price'] = bsc_case['price'].tolist() + czone_case['price'].tolist()
new_case_df['URL'] = bsc_case['url'].tolist() + czone_case['url'].tolist()
new_case_df['Timestamp'] = bsc_case['timestamp'].tolist() + czone_case['timestamp'].tolist()

display(new_case_df)

# %%
new_case_df.to_csv('data/parts/Case_Data(new-excl-old).csv', index=False, encoding='utf-8')

# %%
### Replacing timestamps (cuz it got broken idk how)

timestamp_library = {
    10:07.4 : 2025-03-18 22:10:07.371057	
}

# %% [markdown]
# ### MOBO

# %%
pd.set_option('display.max_rows', None) # Default 60, otherwise None (to see all)

# %%
pc_mobo = pd.read_csv('data/parts/MOBO_Data.csv')
bsc_mobo = pd.read_csv('data/parts/brightstarcomp/motherboard.csv')
czone_mobo = pd.read_csv('data/parts/czone/motherboards.csv')

# %%
print(f'{pc_mobo.columns}\n{bsc_mobo.columns}\n{czone_mobo.columns}')
# Out:
# Index(['Brand', 'Name', 'Socket', 'Size', 'RAM Slot', 'NVME Slot', 'Wifi',
#        'Price'],
#       dtype='object')
# Index(['url', 'name', 'price', 'timestamp', 'Note'], dtype='object')
# Index(['url', 'name', 'price', 'timestamp', 'Note'], dtype='object')

# %%
display(bsc_mobo)

# %%
display(czone_mobo)

# %%
def parse_mobo_details(product_string):
    # Split string
    string = product_string.split()
    
    # Extract brand:
    brand = string[0]

    # Extract name:
    name = " ".join(string[1:])

    # Clean name:
    strings = ['Motherboard', 'Mother Board', 'Mother-Board', 'Motherboard', 'PC Motherboard', 'PC Mother Board', 'PC Mother-Board']
    for string in strings:
        name = name.replace(string, '').strip()

    # Extract socket:
    sockets = ['LGA 1700', 'LGA 1851', 'LGA1700', 'LGA1851', 'AM4', 'AM5']
    socket = next((s for s in sockets if s in product_string), None)
    if socket:
        name = name.replace(socket, '').strip()
    else:
        socket = None

    # Extract size:
    sizes = ['Micro-ATX', 'Mini-ITX', 'E-ATX','EATX', 'mATX','MATX', 'ATX', 'ITX']
    size = next((s for s in sizes if s in product_string), None)
    if size:
        name = name.replace(size, '').strip()
    else:
        size = None
        
    #Extract wifi:
    wifi = next((w for w in ['Wifi', 'Wi-Fi', 'WiFi', 'WIFI'] if w in product_string), None)
    if wifi:
        name = name.replace(wifi, '').strip()
        wifi = 1
    else:
        wifi = None

    # Extract extra data
    extra_data = next((d for d in ['DDR4', 'DDR5'] if d in product_string), None)
    if extra_data:
        name = name.replace(extra_data, '').strip()
    else:
        extra_data = None

    return {
        'Brand': brand,
        'Name': name,
        'Socket': socket,
        'Size': size,
        'RAM Slot': None,
        'NVME Slot': None,
        'Wifi': wifi,
        'Price': None,
        "URL": None,
        "Timestamp": None,
        "Note": extra_data
    }

mobo_name_strings = bsc_mobo['name'].tolist() + czone_mobo['name'].tolist()
new_mobo_df = pd.DataFrame([parse_mobo_details(name) for name in mobo_name_strings])
new_mobo_df['Price'] = bsc_mobo['price'].tolist() + czone_mobo['price'].tolist()
new_mobo_df['URL'] = bsc_mobo['url'].tolist() + czone_mobo['url'].tolist()
new_mobo_df['Timestamp'] = bsc_mobo['timestamp'].tolist() + czone_mobo['timestamp'].tolist()

display(new_mobo_df)

# %%
new_mobo_df.to_csv('data/parts/MOBO_Data(new-excl-old).csv', index=False, encoding='utf-8')

# %%
new_mobo_df = pd.read_csv('data/parts/MOBO_Data(new-excl-old).csv')
display(new_mobo_df)
# Out:
#       Brand                Name   Socket       Size  RAM Slot  NVME Slot  \
# 0    ASRock            A520M/ac      AM4  Micro-ATX       NaN        NaN
# 1    ASRock   A620M-HDV/M.2 AMD      AM5       MATX       NaN        NaN
# 2    ASRock  B450M Steel Legend      AM4  Micro-ATX       NaN        NaN
# 3    ASRock      B450M-HDV R4.0      AM4  Micro-ATX       NaN        NaN
# 4    ASRock        B550M Pro SE      AM4  Micro-ATX       NaN        NaN
# ..      ...                 ...      ...        ...       ...        ...
# 257     MSI         B550M-A Pro      NaN        NaN       NaN        NaN
# 258     MSI       B550M Pro-VDH      NaN        NaN       NaN        NaN
# 259     MSI    B550 Gaming Plus      NaN        NaN       NaN        NaN
# 260    NZXT       N7 Z790 Intel  LGA1700        ATX       NaN        NaN
# 261    NZXT       N7 Z790 Intel  LGA1700        ATX       NaN        NaN
#
#      Wifi   Price                                                URL  \
# 0     1.0   299.0  https://brightstarcomp.com/collections/pc-comp...
# 1     NaN   369.0  https://brightstarcomp.com/collections/pc-comp...
# 2     NaN   399.0  https://brightstarcomp.com/collections/pc-comp...
# 3     NaN   259.0  https://brightstarcomp.com/collections/pc-comp...
# 4     NaN   429.0  https://brightstarcomp.com/collections/pc-comp...
# ..    ...     ...                                                ...
# 257   NaN   319.0  https://czone.my/czone/b550m-a pro-1739103144....
# 258   1.0   459.0  https://czone.my/czone/b550m pro-vdh wifi-1739...
# 259   NaN   549.0  https://czone.my/czone/mpg b550 gaming plus-17...
# 260   NaN  1539.0  https://brightstarcomp.com/collections/pc-comp...
# 261   NaN  1459.0  https://brightstarcomp.com/collections/pc-comp...
#
#                Timestamp   Note
# 0    2025-03-18 22:07:26    NaN
# 1    2025-03-18 22:07:26    NaN
# 2    2025-03-18 22:07:26    NaN
# 3    2025-03-18 22:07:26    NaN
# 4    2025-03-18 22:07:26    NaN
# ..                   ...    ...
# 257  2025-03-19 14:21:27   DDR4
# 258  2025-03-19 14:21:27   DDR4
# 259  2025-03-19 14:21:27   DDR4
# 260  2025-04-11 10:05:00  Black
# 261  2025-04-11 10:05:00  White
#
# [262 rows x 11 columns]

# %%
import re

def clean_price(price):
    # Use regex to remove non-numeric characters except for the decimal point
    cleaned_price = re.sub(r'[^\d.]', '', price)
    return float(cleaned_price) if cleaned_price else None

# new_mobo_df['Price'] = new_mobo_df['Price'].apply(clean_price)

display(new_mobo_df)
# Out:
#       Brand                Name   Socket       Size  RAM Slot  NVME Slot  \
# 0    ASRock            A520M/ac      AM4  Micro-ATX       NaN        NaN
# 1    ASRock   A620M-HDV/M.2 AMD      AM5       MATX       NaN        NaN
# 2    ASRock  B450M Steel Legend      AM4  Micro-ATX       NaN        NaN
# 3    ASRock      B450M-HDV R4.0      AM4  Micro-ATX       NaN        NaN
# 4    ASRock        B550M Pro SE      AM4  Micro-ATX       NaN        NaN
# ..      ...                 ...      ...        ...       ...        ...
# 257     MSI         B550M-A Pro      NaN        NaN       NaN        NaN
# 258     MSI       B550M Pro-VDH      NaN        NaN       NaN        NaN
# 259     MSI    B550 Gaming Plus      NaN        NaN       NaN        NaN
# 260    NZXT       N7 Z790 Intel  LGA1700        ATX       NaN        NaN
# 261    NZXT       N7 Z790 Intel  LGA1700        ATX       NaN        NaN
#
#      Wifi   Price                                                URL  \
# 0     1.0   299.0  https://brightstarcomp.com/collections/pc-comp...
# 1     NaN   369.0  https://brightstarcomp.com/collections/pc-comp...
# 2     NaN   399.0  https://brightstarcomp.com/collections/pc-comp...
# 3     NaN   259.0  https://brightstarcomp.com/collections/pc-comp...
# 4     NaN   429.0  https://brightstarcomp.com/collections/pc-comp...
# ..    ...     ...                                                ...
# 257   NaN   319.0  https://czone.my/czone/b550m-a pro-1739103144....
# 258   1.0   459.0  https://czone.my/czone/b550m pro-vdh wifi-1739...
# 259   NaN   549.0  https://czone.my/czone/mpg b550 gaming plus-17...
# 260   NaN  1539.0  https://brightstarcomp.com/collections/pc-comp...
# 261   NaN  1459.0  https://brightstarcomp.com/collections/pc-comp...
#
#                Timestamp   Note
# 0    2025-03-18 22:07:26    NaN
# 1    2025-03-18 22:07:26    NaN
# 2    2025-03-18 22:07:26    NaN
# 3    2025-03-18 22:07:26    NaN
# 4    2025-03-18 22:07:26    NaN
# ..                   ...    ...
# 257  2025-03-19 14:21:27   DDR4
# 258  2025-03-19 14:21:27   DDR4
# 259  2025-03-19 14:21:27   DDR4
# 260  2025-04-11 10:05:00  Black
# 261  2025-04-11 10:05:00  White
#
# [262 rows x 11 columns]

# %%
## Merge MOBO dataset
notPC_mobo = pd.read_csv('data/parts/MOBO_Data(new-excl-old).csv')

mobo_merged = pd.merge(pc_mobo, new_mobo_df, how='outer')
# Remove Chipset blankspace
mobo_merged['Socket'] = [str(socket).replace(' ', '') for socket in mobo_merged['Socket']]


display(mobo_merged)
# mobo_merged.to_csv('data/parts/MOBO_Data(new).csv', index=False, encoding='utf-8')
# Out:
#       Brand                Name   Socket       Size  RAM Slot  NVME Slot  \
# 0    ASRock            A520M/ac      AM4  Micro-ATX       NaN        NaN
# 1    ASRock   A620M-HDV/M.2 AMD      AM5       MATX       NaN        NaN
# 2    ASRock  B450M Steel Legend      AM4  Micro-ATX       NaN        NaN
# 3    ASRock      B450M-HDV R4.0      AM4  Micro-ATX       NaN        NaN
# 4    ASRock           B550M  SE      AM4  Micro-ATX       NaN        NaN
# ..      ...                 ...      ...        ...       ...        ...
# 282     MSI      X870E Tomahawk      nan        NaN       NaN        NaN
# 283     MSI   Z790 PROJECT ZERO  LGA1700        ATX       NaN        NaN
# 284     MSI       Z890 Tomahawk      nan        NaN       NaN        NaN
# 285    NZXT       N7 Z790 Intel  LGA1700        ATX       NaN        NaN
# 286    NZXT       N7 Z790 Intel  LGA1700        ATX       NaN        NaN
#
#      Wifi   Price                                                URL  \
# 0     1.0   299.0  https://brightstarcomp.com/collections/pc-comp...
# 1     NaN   369.0  https://brightstarcomp.com/collections/pc-comp...
# 2     NaN   399.0  https://brightstarcomp.com/collections/pc-comp...
# 3     NaN   259.0  https://brightstarcomp.com/collections/pc-comp...
# 4     1.0   469.0  https://brightstarcomp.com/collections/pc-comp...
# ..    ...     ...                                                ...
# 282   1.0  1799.0  https://czone.my/czone/mag x870e tomahawk wifi...
# 283   NaN  1399.0  https://brightstarcomp.com/collections/pc-comp...
# 284   1.0  1699.0  https://czone.my/czone/mag z890 tomahawk wifi-...
# 285   NaN  1459.0  https://brightstarcomp.com/collections/pc-comp...
# 286   NaN  1539.0  https://brightstarcomp.com/collections/pc-comp...
#
#                Timestamp   Note
# 0    2025-03-18 22:07:26    NaN
# 1    2025-03-18 22:07:26    NaN
# 2    2025-03-18 22:07:26    NaN
# 3    2025-03-18 22:07:26    NaN
# 4    2025-03-18 22:07:26    NaN
# ..                   ...    ...
# 282  2025-03-19 14:21:21   DDR5
# 283  2025-03-18 22:07:34    NaN
# 284  2025-03-19 14:21:21   DDR5
# 285  2025-04-11 10:05:00  White
# 286  2025-04-11 10:05:00  Black
#
# [287 rows x 11 columns]
