# %% [markdown]
# # Non-dominated Sorting Genetic Algorithm II (NSGA-II)

# %% [markdown]
# It gives several builds at the end of it

# %%
# required for running NSGA-ii

# !pip install pymoo

# %%
import numpy as np
import pandas as pd
from pymoo.core.problem import ElementwiseProblem
from pymoo.optimize import minimize
from pymoo.algorithms.moo.nsga2 import NSGA2
from pymoo.termination import get_termination

# %%
path = "../data/parts/"

# Load datasets
games_df = pd.read_csv("../data/games/top300.csv")

cpu_df = pd.read_csv(path + "CPU_Data.csv")
gpu_df = pd.read_csv(path + "GPU_Data.csv")
ram_df = pd.read_csv(path + "RAM_Data.csv")

mobo_df = pd.read_csv(path + "MOBO_Data.csv")
psu_df = pd.read_csv(path + "PSU_Data.csv")
case_df = pd.read_csv(path + "Case_Data.csv")

# storage_df = pd.read_csv(data_path + "Storage_Data.csv")

def safe_to_numeric(value):
    try:
        return pd.to_numeric(value)
    except (ValueError, TypeError):
        return value  

# Convert columns to numeric where possible
games_df = games_df.apply(safe_to_numeric)
cpu_df = cpu_df.apply(safe_to_numeric)
gpu_df = gpu_df.apply(safe_to_numeric)
ram_df = ram_df.apply(safe_to_numeric)
case_df = case_df.apply(safe_to_numeric)
mobo_df = mobo_df.apply(safe_to_numeric)
psu_df = psu_df.apply(safe_to_numeric)

# storage_df = storage_df.apply(safe_to_numeric)

# %%
# Precompute valid CPU-MOBO pairs
valid_cpu_mobo_pairs = cpu_df.merge(
    mobo_df, on="Socket", suffixes=("_cpu", "_mobo")
).reset_index(drop=True)

# Set ram options
ram_stick_options = [1, 2, 4]

# %%
# Maximize budget
class PCBuildProblem(ElementwiseProblem):
    def __init__(self, budget, required_cpu_score, required_gpu_score, required_ram_gb):
        self.budget = budget
        self.required_cpu_score = required_cpu_score
        self.required_gpu_score = required_gpu_score
        self.required_ram_gb = max(required_ram_gb, 8)  # Enforce minimum 8 GB RAM

        super().__init__(
            n_var=6,  # [cpu_mobo, gpu, ram, ram_stick_count, psu, case]
            n_obj=3,  # Maximize CPU score, GPU score, dual channel
            n_constr=8,  # Now includes CPU and GPU score requirements
            xl=np.array([0, 0, 0, 0, 0, 0]),
            xu=np.array([
                len(valid_cpu_mobo_pairs) - 1,
                len(gpu_df) - 1,
                len(ram_df) - 1,
                len(ram_stick_options) - 1,
                len(psu_df) - 1,
                len(case_df) - 1
            ])
        )

    def _evaluate(self, x, out, *args, **kwargs):
        cpu_mobo = valid_cpu_mobo_pairs.iloc[int(x[0])]
        gpu = gpu_df.iloc[int(x[1])]
        ram = ram_df.iloc[int(x[2])]
        sticks = ram_stick_options[int(x[3])]
        psu = psu_df.iloc[int(x[4])]
        case = case_df.iloc[int(x[5])]

        total_ram = ram['Capacity (GB)'] * sticks
        total_price = (
            cpu_mobo['Price_cpu'] + cpu_mobo['Price_mobo'] +
            gpu['Price'] + psu['Price'] + case['Price'] +
            ram['Price'] * sticks
        )

        cpu_score = cpu_mobo['Score']
        gpu_score = gpu['Score']

        # Constraint checks
        wattage_ok = psu['Wattage'] >= gpu['Recommended Power']
        case_ok = str(cpu_mobo['Size']) in str(case['Size'])
        ram_slot_ok = sticks <= cpu_mobo['RAM Slot']
        ddr_ok = str(ram['DDR']) == str(cpu_mobo['DDR'])
        min_ram_ok = total_ram >= self.required_ram_gb
        budget_ok = total_price <= self.budget
        cpu_ok = cpu_score >= self.required_cpu_score
        gpu_ok = gpu_score >= self.required_gpu_score

        # Dual-channel preference
        dual_channel_score = 1 if sticks in [2, 4] else 0

        # Objectives (maximize → negate)
        out["F"] = [
            -cpu_score,
            -gpu_score,
            -dual_channel_score
        ]

        # Constraints: must be <= 0 to be feasible
        out["G"] = [
            0 if wattage_ok else 1,
            0 if case_ok else 1,
            0 if ram_slot_ok else 1,
            0 if ddr_ok else 1,
            0 if min_ram_ok else 1,
            0 if budget_ok else 1,
            0 if cpu_ok else 1,
            0 if gpu_ok else 1 
        ]

# %%
budget = 2500
required_cpu_score = 10000
required_gpu_score = 13000
required_ram_gb = 16

problem = PCBuildProblem(budget, required_cpu_score, required_gpu_score, required_ram_gb)

# Run NSGA-II
algorithm = NSGA2(pop_size=100)
termination = get_termination("n_gen", 50)
res = minimize(problem, algorithm, termination, seed=1, save_history=True, verbose=True)

# Display results
for i, sol in enumerate(res.X):
    cpu_mobo = valid_cpu_mobo_pairs.iloc[int(sol[0])]
    gpu = gpu_df.iloc[int(sol[1])]
    ram = ram_df.iloc[int(sol[2])]
    sticks = ram_stick_options[int(sol[3])]
    psu = psu_df.iloc[int(sol[4])]
    case = case_df.iloc[int(sol[5])]

    total_price = (
        cpu_mobo['Price_cpu'] + cpu_mobo['Price_mobo'] +
        gpu['Price'] + psu['Price'] + case['Price'] +
        ram['Price'] * sticks
    )

    print(f"\nBuild {i + 1}:")
    print("CPU:", cpu_mobo['Name_cpu'])
    print("MOBO:", cpu_mobo['Name_mobo'])
    print("GPU:", gpu['Name'])
    print("RAM:", f"{sticks}x {ram['Name']}")
    print("PSU:", psu['Name'])
    print("Case:", case['Name'])
    print(f"Total Price: RM{total_price:.2f}")
    print("CPU Score:", -res.F[i][0])
    print("GPU Score:", -res.F[i][1])
# Out:
# ==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |      100 |      1 |  0.000000E+00 |  2.8400000000 |             - |             -
#      2 |      200 |      2 |  0.000000E+00 |  1.8900000000 |  1.0000000000 |         ideal
#      3 |      300 |      2 |  0.000000E+00 |  1.4300000000 |  0.000000E+00 |             f
#      4 |      400 |      2 |  0.000000E+00 |  0.9300000000 |  0.6161473088 |         ideal
#      5 |      500 |      1 |  0.000000E+00 |  0.8500000000 |  9.600000E+02 |         ideal
#      6 |      600 |      2 |  0.000000E+00 |  0.7600000000 |  1.0000000000 |         ideal
#      7 |      700 |      3 |  0.000000E+00 |  0.6200000000 |  0.000000E+00 |             f
#      8 |      800 |      5 |  0.000000E+00 |  0.3400000000 |  0.000000E+00 |             f
#      9 |      900 |     12 |  0.000000E+00 |  0.000000E+00 |  0.0898312118 |             f
#     10 |     1000 |     15 |  0.000000E+00 |  0.000000E+00 |  0.3912175649 |         nadir
#     11 |     1100 |      3 |  0.000000E+00 |  0.000000E+00 |  3.1348484848 |         nadir
#     12 |     1200 |      7 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     13 |     1300 |      3 |  0.000000E+00 |  0.000000E+00 |  1.0000000000 |         ideal
#     14 |     1400 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     15 |     1500 |      9 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     16 |     1600 |     11 |  0.000000E+00 |  0.000000E+00 |  1.0000000000 |         nadir
#     17 |     1700 |     21 |  0.000000E+00 |  0.000000E+00 |  1.0000000000 |         nadir
#     18 |     1800 |     39 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     19 |     1900 |     68 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     20 |     2000 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     21 |     2100 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     22 |     2200 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     23 |     2300 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     24 |     2400 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     25 |     2500 |      1 |  0.000000E+00 |  0.000000E+00 |  1.830000E+03 |         nadir
#     26 |     2600 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     27 |     2700 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     28 |     2800 |      6 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     29 |     2900 |     12 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     30 |     3000 |     22 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     31 |     3100 |     46 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     32 |     3200 |      1 |  0.000000E+00 |  0.000000E+00 |  6.520000E+02 |         ideal
#     33 |     3300 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     34 |     3400 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     35 |     3500 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     36 |     3600 |      8 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     37 |     3700 |     15 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     38 |     3800 |     24 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     39 |     3900 |     46 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     40 |     4000 |     81 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     41 |     4100 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     42 |     4200 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     43 |     4300 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     44 |     4400 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     45 |     4500 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     46 |     4600 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     47 |     4700 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     48 |     4800 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     49 |     4900 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     50 |     5000 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#
# Build 1:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: Mirage 650W
# Case: A21
# Total Price: RM2346.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 2:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: P650G
# Case: MAG Pano M100R PZ
# Total Price: RM2455.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 3:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MPG A750GF
# Case: Nexus Air M3 Omni
# Total Price: RM2325.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 4:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: D7
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 5:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 6:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: P2 Storm
# Total Price: RM2375.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 7:
# CPU: Ryzen 7 3700X
# MOBO: B550M-HDV
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x CRAS XR RGB
# PSU: P650G
# Case: Nexus Air T3
# Total Price: RM2397.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 8:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MPG A750GF
# Case: Nexus Air M3 Omni
# Total Price: RM2325.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 9:
# CPU: Ryzen 7 3700X
# MOBO: B550M-HDV
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air M3 Omni
# Total Price: RM2225.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 10:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 11:
# CPU: Ryzen 7 3700X
# MOBO: A520M-A PRO
# GPU: PowerColor RX 5700 8GB Red Devil
# RAM: 2x 16GB
# PSU: PF650
# Case: Nexus Air M3 Omni
# Total Price: RM2065.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 12:
# CPU: Ryzen 7 3700X
# MOBO: B550M-HDV
# GPU: RX 5700XT 50th Anniversary
# RAM: 2x 32GB
# PSU: P650G
# Case: Nexus Air T3
# Total Price: RM2465.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 13:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: Nexus Air T3 Omni
# Total Price: RM2465.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 14:
# CPU: Ryzen 7 3700X
# MOBO: B450M Pro-VDH Max
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: MWE Gold 650
# Case: Nexus Air T3 Omni
# Total Price: RM2375.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 15:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 16:
# CPU: Ryzen 7 3700X
# MOBO: A520M/ac WiFi
# GPU: XFX RX 5700 XT 8GB Thicc III Ultra
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: BX Mini
# Total Price: RM2142.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 17:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: PF650
# Case: Nexus Air T3 Omni
# Total Price: RM2075.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 18:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2215.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 19:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: Mirage 650W
# Case: A21
# Total Price: RM2346.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 20:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 21:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MWE Gold 650
# Case: Nexus Air T3 Omni
# Total Price: RM2325.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 22:
# CPU: Ryzen 7 3700X
# MOBO: B450M Pro-VDH Max
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: MWE Gold 650
# Case: Nexus Air T3 Omni
# Total Price: RM2375.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 23:
# CPU: Ryzen 7 3700X
# MOBO: B550M-A Pro
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2241.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 24:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air T3 Omni
# Total Price: RM2125.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 25:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: RX 5700XT 50th Anniversary
# RAM: 2x 16GB
# PSU: LitePower 650W
# Case: MAG Pano M100R PZ
# Total Price: RM2356.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 26:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: P650G
# Case: MAG Pano M100R PZ
# Total Price: RM2435.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 27:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MWE Gold 650
# Case: Nexus Air T3 Omni
# Total Price: RM2325.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 28:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Fusion 2 Air
# Total Price: RM2235.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 29:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Gold 650
# Case: Nexus Air T3 Omni
# Total Price: RM2325.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 30:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: UV6
# Total Price: RM2255.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 31:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: V150
# Total Price: RM2165.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 32:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Gigabyte RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: Fusion 2 Air
# Total Price: RM2415.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 33:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 34:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x DDR4
# PSU: Mirage 650W
# Case: Nexus Air T3 Omni
# Total Price: RM2055.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 35:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III
# RAM: 2x DDR4
# PSU: MWE Bronze 650 V3
# Case: P2 Storm
# Total Price: RM2061.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 36:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: Prime 750W
# Case: Nexus Air T3 Omni
# Total Price: RM2496.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 37:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 38:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 8GB
# PSU: HV Pro
# Case: Nexus Air T3 Omni
# Total Price: RM2055.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 39:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 8GB
# PSU: MWE Bronze 750 V3
# Case: T4
# Total Price: RM2091.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 40:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2181.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 41:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: P650SS
# Case: Fara 312X
# Total Price: RM2135.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 42:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: A21
# Total Price: RM2346.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 43:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III
# RAM: 2x CRAS XR RGB
# PSU: MWE Gold 850 V2
# Case: V150
# Total Price: RM2495.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 44:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air T3 Omni
# Total Price: RM2125.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 45:
# CPU: Ryzen 7 3700X
# MOBO: B550M-HDV
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2231.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 46:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Asus RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Fara 312X
# Total Price: RM2171.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 47:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Fara 312X
# Total Price: RM2205.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 48:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: PowerColor RX 5700 8GB
# RAM: 2x 16GB
# PSU: PF650
# Case: Fara 312X
# Total Price: RM2085.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 49:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air T3 Omni
# Total Price: RM2155.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 50:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: T4
# Total Price: RM2351.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 51:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: T4
# Total Price: RM2151.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 52:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Gigabyte RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: Fusion 2 Air
# Total Price: RM2415.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 53:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 54:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: Elegant M8
# Total Price: RM2145.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 55:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: RX 5700XT 50th Anniversary
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 56:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: RX 5700
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Fusion 2 Air
# Total Price: RM2235.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 57:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Asus RX 5700 XT 8GB
# RAM: 2x CRAS XR RGB
# PSU: MWE Bronze 650 V3
# Case: Fara 312X
# Total Price: RM2343.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 58:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III Ultra
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air M3 Omni
# Total Price: RM2155.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 59:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 60:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 61:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MAG A750BN
# Case: Nexus Air T3 Omni
# Total Price: RM2235.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 62:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air T3 Omni
# Total Price: RM2155.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 63:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air T3 Omni
# Total Price: RM2125.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 64:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air M3 Omni
# Total Price: RM2125.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 65:
# CPU: Ryzen 7 3700X
# MOBO: B550M-A Pro
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2241.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 66:
# CPU: Ryzen 7 3700X
# MOBO: A520M/ac WiFi
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air M3 Omni
# Total Price: RM2165.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 67:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: PF650
# Case: Nexus Air T3 Omni
# Total Price: RM2095.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 68:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: RX 5700-XT
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air M3 Omni
# Total Price: RM2155.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 69:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air T3 Omni
# Total Price: RM2155.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 70:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: RX 5700
# RAM: 2x 32GB
# PSU: MWE Bronze 750 V3
# Case: Fusion 2 Air
# Total Price: RM2475.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 71:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: T4
# Total Price: RM2351.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 72:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 73:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air M3 Omni
# Total Price: RM2145.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 74:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: PowerColor RX 5700 8GB
# RAM: 2x 16GB
# PSU: PK750D
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 75:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: V150
# Total Price: RM2171.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 76:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Asus RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 77:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 78:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III
# RAM: 2x CRAS XR RGB
# PSU: MWE Bronze 650 V3
# Case: P2 Storm
# Total Price: RM2141.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 79:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: MSI RX 5700 XT 8GB Gaming
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: Elegant M8
# Total Price: RM2475.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 80:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: PowerColor RX 5700 8GB
# RAM: 2x 8GB
# PSU: PK650D
# Case: Nexus Air T3 Omni
# Total Price: RM2031.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 81:
# CPU: Ryzen 7 3700X
# MOBO: B550M-HDV
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x CRAS XR RGB
# PSU: P650G
# Case: P1 Gateway
# Total Price: RM2367.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 82:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: Mag A750GL
# Case: Nexus Air M3 Omni
# Total Price: RM2457.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 83:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: T4
# Total Price: RM2351.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 84:
# CPU: Ryzen 7 3700X
# MOBO: B550M-A Pro
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2241.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 85:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB Thicc III
# RAM: 2x 16GB
# PSU: Leadex III
# Case: Nexus Air T3 Omni
# Total Price: RM2425.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 86:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: Fusion 2 Air
# Total Price: RM2415.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 87:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Asus RX 5700 XT 8GB ROG Strix
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air T3 Omni
# Total Price: RM2125.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 88:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Asus RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 89:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: NGDP ATX 3.1
# Case: Nexus Air M3 Omni
# Total Price: RM2341.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 90:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Nitro+
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: D7
# Total Price: RM2185.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 91:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Asus RX 5700 XT 8GB ROG Strix
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: T4
# Total Price: RM2201.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 92:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: T3
# Total Price: RM2157.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 93:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 94:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB Pulse
# RAM: 2x 16GB
# PSU: P650G
# Case: Fusion 2 Air
# Total Price: RM2215.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 95:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2215.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 96:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: Nexus Air T3 Omni
# Total Price: RM2161.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 97:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: Sapphire RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 750 V3
# Case: Nexus Air M3 Omni
# Total Price: RM2195.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 98:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650G
# Case: Nexus Air T3
# Total Price: RM2155.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 99:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: MWE Bronze 650 V3
# Case: P2 Storm
# Total Price: RM2181.00
# CPU Score: 22521.0
# GPU Score: 16515.0
#
# Build 100:
# CPU: Ryzen 7 3700X
# MOBO: PRIME A520M-K
# GPU: XFX RX 5700 XT 8GB
# RAM: 2x 16GB
# PSU: P650SS
# Case: Nexus Air T3 Omni
# Total Price: RM2125.00
# CPU Score: 22521.0
# GPU Score: 16515.0

# %%
class PCBuildCostMinProblem(ElementwiseProblem):
    def __init__(self, budget, required_cpu_score, required_gpu_score, required_ram_gb):
        self.budget = budget
        self.required_cpu_score = required_cpu_score
        self.required_gpu_score = required_gpu_score
        self.required_ram_gb = max(required_ram_gb, 8)  # Enforce minimum 8GB RAM

        super().__init__(
            n_var=6,  # [cpu_mobo_index, gpu_index, ram_index, ram_sticks, psu_index, case_index]
            n_obj=1,  # minimize total price
            n_constr=6,  # CPU, GPU, PSU, RAM, case, and budget
            xl=np.array([0, 0, 0, 0, 0, 0]),
            xu=np.array([
                len(valid_cpu_mobo_pairs) - 1,
                len(gpu_df) - 1,
                len(ram_df) - 1,
                len(ram_stick_options) - 1,
                len(psu_df) - 1,
                len(case_df) - 1
            ])
        )

    def _evaluate(self, x, out, *args, **kwargs):
        cpu_mobo = valid_cpu_mobo_pairs.iloc[int(x[0])]
        gpu = gpu_df.iloc[int(x[1])]
        ram = ram_df.iloc[int(x[2])]
        sticks = ram_stick_options[int(x[3])]
        psu = psu_df.iloc[int(x[4])]
        case = case_df.iloc[int(x[5])]

        total_ram = ram['Capacity (GB)'] * sticks
        total_price = (
            cpu_mobo['Price_cpu'] + cpu_mobo['Price_mobo'] +
            gpu['Price'] + psu['Price'] + case['Price'] +
            ram['Price'] * sticks
        )

        cpu_score = cpu_mobo['Score']
        gpu_score = gpu['Score']

        # Constraints
        wattage_ok = psu['Wattage'] >= gpu['Recommended Power']
        case_ok = str(cpu_mobo['Size']) in str(case['Size'])
        ram_slot_ok = sticks <= cpu_mobo['RAM Slot']
        ddr_ok = str(ram['DDR']) == str(cpu_mobo['DDR'])
        min_ram_ok = total_ram >= self.required_ram_gb
        cpu_ok = cpu_score >= self.required_cpu_score
        gpu_ok = gpu_score >= self.required_gpu_score
        budget_ok = total_price <= self.budget

        out["F"] = [total_price]  # pure cost minimization
        out["G"] = [
            0 if cpu_ok else 1,
            0 if gpu_ok else 1,
            0 if wattage_ok else 1,
            0 if case_ok else 1,
            0 if ram_slot_ok and ddr_ok and min_ram_ok else 1,
            0 if budget_ok else 1  # <-- HARD budget constraint
        ]

# %%
budget = 2500
required_cpu_score = 6000
required_gpu_score = 8000
required_ram_gb = 16

problem = PCBuildCostMinProblem(budget, required_cpu_score, required_gpu_score, required_ram_gb)

# Run NSGA-II
algorithm = NSGA2(pop_size=100)
termination = get_termination("n_gen", 50)
res = minimize(problem, algorithm, termination, seed=1, save_history=True, verbose=True)

# Display results
for i, sol in enumerate(res.X):
    cpu_mobo = valid_cpu_mobo_pairs.iloc[int(sol[0])]
    gpu = gpu_df.iloc[int(sol[1])]
    
    cpu_score = cpu_mobo['Score']
    gpu_score = gpu['Score']
    
    print(f"\nBuild {i + 1}:")
    print("CPU:", valid_cpu_mobo_pairs.iloc[int(sol[0])]['Name_cpu'])
    print("MOBO:", valid_cpu_mobo_pairs.iloc[int(sol[0])]['Name_mobo'])
    print("GPU:", gpu_df.iloc[int(sol[1])]['Name'])
    print("RAM:", f"{ram_stick_options[int(sol[3])]}x {ram_df.iloc[int(sol[2])]['Name']}")
    print("PSU:", psu_df.iloc[int(sol[4])]['Name'])
    print("Case:", case_df.iloc[int(sol[5])]['Name'])
    print("Total Price:", res.F[i][0])
    print("CPU Score:", cpu_score)
    print("GPU Score:", gpu_score)
# Out:
# ==========================================================================================
# n_gen  |  n_eval  | n_nds  |     cv_min    |     cv_avg    |      eps      |   indicator
# ==========================================================================================
#      1 |      100 |      1 |  0.000000E+00 |  1.4900000000 |             - |             -
#      2 |      200 |      1 |  0.000000E+00 |  0.7300000000 |  3.600000E+02 |         ideal
#      3 |      300 |      1 |  0.000000E+00 |  0.4200000000 |  0.000000E+00 |             f
#      4 |      400 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      5 |      500 |      1 |  0.000000E+00 |  0.000000E+00 |  1.840000E+02 |         ideal
#      6 |      600 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#      7 |      700 |      1 |  0.000000E+00 |  0.000000E+00 |  3.000000E+01 |         ideal
#      8 |      800 |      1 |  0.000000E+00 |  0.000000E+00 |  3.200000E+02 |         ideal
#      9 |      900 |      1 |  0.000000E+00 |  0.000000E+00 |  3.000000E+01 |         ideal
#     10 |     1000 |      1 |  0.000000E+00 |  0.000000E+00 |  1.000000E+01 |         ideal
#     11 |     1100 |      1 |  0.000000E+00 |  0.000000E+00 |  1.700000E+02 |         ideal
#     12 |     1200 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     13 |     1300 |      1 |  0.000000E+00 |  0.000000E+00 |  5.0000000000 |         ideal
#     14 |     1400 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     15 |     1500 |      1 |  0.000000E+00 |  0.000000E+00 |  1.0000000000 |         ideal
#     16 |     1600 |      1 |  0.000000E+00 |  0.000000E+00 |  8.900000E+01 |         ideal
#     17 |     1700 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     18 |     1800 |      1 |  0.000000E+00 |  0.000000E+00 |  2.100000E+01 |         ideal
#     19 |     1900 |      1 |  0.000000E+00 |  0.000000E+00 |  1.900000E+01 |         ideal
#     20 |     2000 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     21 |     2100 |      1 |  0.000000E+00 |  0.000000E+00 |  5.000000E+01 |         ideal
#     22 |     2200 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     23 |     2300 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     24 |     2400 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     25 |     2500 |      1 |  0.000000E+00 |  0.000000E+00 |  1.000000E+01 |         ideal
#     26 |     2600 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     27 |     2700 |      1 |  0.000000E+00 |  0.000000E+00 |  3.000000E+01 |         ideal
#     28 |     2800 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     29 |     2900 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     30 |     3000 |      1 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     31 |     3100 |      2 |  0.000000E+00 |  0.000000E+00 |  8.0000000000 |         ideal
#     32 |     3200 |      1 |  0.000000E+00 |  0.000000E+00 |  1.000000E+01 |         ideal
#     33 |     3300 |      3 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     34 |     3400 |      1 |  0.000000E+00 |  0.000000E+00 |  1.300000E+01 |         ideal
#     35 |     3500 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     36 |     3600 |      1 |  0.000000E+00 |  0.000000E+00 |  5.0000000000 |         ideal
#     37 |     3700 |      2 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     38 |     3800 |      7 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     39 |     3900 |     16 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     40 |     4000 |     30 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     41 |     4100 |      2 |  0.000000E+00 |  0.000000E+00 |  1.0000000000 |         ideal
#     42 |     4200 |      4 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     43 |     4300 |      5 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     44 |     4400 |     13 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     45 |     4500 |     23 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     46 |     4600 |     43 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     47 |     4700 |     74 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     48 |     4800 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     49 |     4900 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#     50 |     5000 |    100 |  0.000000E+00 |  0.000000E+00 |  0.000000E+00 |             f
#
# Build 1:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: GTX 1060-6GB
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 2:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 3:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Windforce OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 4:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 5:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 6:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 7:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 8:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 9:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 10:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 11:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 12:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 13:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 14:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 15:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming R2
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 16:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Windforce OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 17:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 18:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB  SC Ultra Dual
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 19:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 20:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1060 6GB Gaming X
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 21:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB Gaming OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 22:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1060 6G Armor OCV1
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 23:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 24:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 25:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 26:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 27:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 28:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 29:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Zotac GTX 1060 6GB AMP
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 30:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming R2
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 31:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 32:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: GTX 1660
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 33:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 34:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 35:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1060 6GB Gaming X
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 36:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 37:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 38:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB  SC Ultra Dual
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 39:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 40:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1060 6GB Gaming X
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 41:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Windforce OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 42:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 43:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: GTX 1660
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 44:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming R2
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 45:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 46:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 47:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 48:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming R2
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 49:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB Gaming OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 50:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 51:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1660 6GB Phoenix
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 52:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 53:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 54:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB  SC Ultra Dual
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 55:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 56:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 57:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 58:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 59:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 60:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB Gaming OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 61:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1060 6G Armor OCV1
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 62:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 63:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming R2
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 64:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: GTX 1060-6GB
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 65:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Windforce OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 66:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 67:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB Gaming OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 68:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB Gaming OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 69:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 70:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB G1 Gaming R2
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 71:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 72:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 73:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 74:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1660 6GB Gaming X
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 75:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 76:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 77:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 78:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 79:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 80:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 81:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: GTX 1660
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 82:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB Gaming OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 83:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 84:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 85:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 86:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 87:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB TURBO
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 88:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 89:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Windforce OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 90:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Asus GTX 1060 6GB ROG STRIX OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 91:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 92:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 93:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Windforce OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 94:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB  SC Ultra Dual
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 95:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 96:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: EVGA GTX 1660 6GB XC Ultra Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 97:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 98:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1660 6GB OC
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667
#
# Build 99:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: Gigabyte GTX 1060 6GB Xtreme Gaming
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 10080
#
# Build 100:
# CPU: Ryzen 3 1200
# MOBO: A520M-A Pro
# GPU: MSI GTX 1660 6GB Gaming X
# RAM: 2x UD01
# PSU: PK550D
# Case: Neo M2
# Total Price: 1109.0
# CPU Score: 6282
# GPU Score: 11667

# %%
def buildPC_NSGA(game_names: list[str], budget: float, mode: str = "performance"):
    # Normalize game names for comparison
    game_names_lower = [name.lower() for name in game_names]
    matched_games = games_df[games_df["name"].str.lower().isin(game_names_lower)]

    if matched_games.empty:
        raise ValueError("None of the specified games were found in the dataset.")

    missing = [name for name in game_names if name.lower() not in matched_games["name"].str.lower().values]
    if missing:
        print(f"Warning: These games were not found and will be skipped: {', '.join(missing)}")

    try:
        required_cpu_score = matched_games["CPU"].astype(float).max()
        required_gpu_score = matched_games["GPU"].astype(float).max()
        required_ram_gb = matched_games["memory"].astype(int).max()
    except Exception as e:
        raise ValueError(f"Failed to extract requirements from one or more games: {e}")

    print(f"Aggregated Requirements — CPU: {required_cpu_score}, GPU: {required_gpu_score}, RAM: {required_ram_gb}GB")

    if mode == "performance":
        return PCBuildProblem(
            budget=budget,
            required_cpu_score=required_cpu_score,
            required_gpu_score=required_gpu_score,
            required_ram_gb=required_ram_gb
        )
    elif mode == "cost":
        return PCBuildCostMinProblem(
            budget=budget,
            required_cpu_score=required_cpu_score,
            required_gpu_score=required_gpu_score,
            required_ram_gb=required_ram_gb
        )
    else:
        raise ValueError(f"Unknown mode '{mode}'. Choose 'performance' or 'cost'.")

# %%
# Performance-focused build (maximize CPU/GPU/dual-channel)
problem = buildPC_NSGA(["Elden Ring", "Cyberpunk 2077"], budget=3000, mode="performance")

# Cost-minimized build (satisfy constraints with lowest price)
# problem = buildPC_NSGA(["Elden Ring", "Cyberpunk 2077"], budget=3000, mode="cost")

algorithm = NSGA2(pop_size=100)
termination = get_termination("n_gen", 50)
res = minimize(problem, algorithm, termination, seed=1, save_history=True, verbose=True)

# Display results
for i, sol in enumerate(res.X):
    cpu_mobo = valid_cpu_mobo_pairs.iloc[int(sol[0])]
    gpu = gpu_df.iloc[int(sol[1])]
    
    cpu_score = cpu_mobo['Score']
    gpu_score = gpu['Score']
    
    print(f"\nBuild {i + 1}:")
    print("CPU:", valid_cpu_mobo_pairs.iloc[int(sol[0])]['Name_cpu'])
    print("MOBO:", valid_cpu_mobo_pairs.iloc[int(sol[0])]['Name_mobo'])
    print("GPU:", gpu_df.iloc[int(sol[1])]['Name'])
    print("RAM:", f"{ram_stick_options[int(sol[3])]}x {ram_df.iloc[int(sol[2])]['Name']}")
    print("PSU:", psu_df.iloc[int(sol[4])]['Name'])
    print("Case:", case_df.iloc[int(sol[5])]['Name'])
    print("Total Price:", res.F[i][0])
    print("CPU Score:", cpu_score)
    print("GPU Score:", gpu_score)
